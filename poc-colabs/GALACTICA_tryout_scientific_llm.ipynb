# %% [markdown]
# <a href="https://colab.research.google.com/github/moulaali/ml/blob/master/poc-colabs/GALACTICA_tryout_scientific_llm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install galai
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.4/302.4 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.9/160.9 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 25.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...

# %%
from google.colab import userdata
userdata.get('HF_TOKEN')
# Out:
# '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'

# %%
import galai as gal
model = gal.load_model("mini")
model.generate("The Schwarzschild radius is defined as: \\[")
# Out:
# tokenizer_config.json:   0%|          | 0.00/166 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.14M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.00 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/787 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/250M [00:00<?, ?B/s]
# 'The Schwarzschild radius is defined as: \\[ r_{S}=\\frac{GM}{c^{2}}\\frac{1}{\\sqrt{1-\\frac{2M}{r_{S}}}}\\ , \\] (1)\n\nwhere \\('

# %%
model.generate("The reason why Transformers replaced RNNs was because", new_doc=False)
# Out:
# 'The reason why Transformers replaced RNNs was because they were able to learn the dependencies between the tokens in the input sequence.\n\n# 3.2.2. Attention Mechanism\n\nAttention mechanism is a powerful technique to capture the dependencies between tokens in the input sequence.\nThe attention mechanism is a technique to compute the attention between two tokens'

# %%
# Reasoning
model.generate("A force of 0.6N is applied to an object, which accelerates at 3m/s. What is its mass?", new_doc=False)
# Out:
# 'A force of 0.6N is applied to an object, which accelerates at 3m/s. What is its mass?\n\nAnswer: 1.5kg\n\n'
